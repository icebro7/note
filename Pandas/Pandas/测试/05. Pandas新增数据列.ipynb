# %%
import pandas as pd

# %%
#读取csv文件
fpath = "../datas/beijing_tianqi/beijing_tianqi_2018.csv"
df=pd.read_csv(fpath)
df
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
#将℃去除
df['bWendu']=df['bWendu'].str.replace('℃','').astype('int32')
df['yWendu']=df['yWendu'].str.replace('℃','').astype('int32')
df
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 3    2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1
# ..          ...     ...     ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27      -5     -12   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28      -3     -11      晴       西北风     3级   40       优         1
# 362  2018-12-29      -3     -12      晴       西北风     2级   29       优         1
# 363  2018-12-30      -2     -11   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31      -2     -10     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
#新增一列查看温差
df['wencha']=df['bWendu']-df['yWendu']
df
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  \
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良
# 1    2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优
# 2    2018-01-03       2      -5     多云        北风   1-2级   28       优
# 3    2018-01-04       0      -8      阴       东北风   1-2级   28       优
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优
# ..          ...     ...     ...    ...       ...    ...  ...     ...
# 360  2018-12-27      -5     -12   多云~晴       西北风     3级   48       优
# 361  2018-12-28      -3     -11      晴       西北风     3级   40       优
# 362  2018-12-29      -3     -12      晴       西北风     2级   29       优
# 363  2018-12-30      -2     -11   晴~多云       东北风     1级   31       优
# 364  2018-12-31      -2     -10     多云       东北风     1级   56       良
#
#      aqiLevel  wencha
# 0           2       9
# 1           1       7
# 2           1       7
# 3           1       8
# 4           1       9
# ..        ...     ...
# 360         1       7
# 361         1       8
# 362         1       9
# 363         1       9
# 364         2       8
#
# [365 rows x 10 columns]

# %%
#新增一列 统计温差是否过大 大于10显示温差过大否者正常
def get_wendu_type(x):
    if x["bWendu"] > 33:
        return '高温'
    if x["yWendu"] < -10:
        return '低温'
    return '常温'
    
df['tongji']=df.apply(get_wendu_type,axis=1)
df
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  \
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良
# 1    2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优
# 2    2018-01-03       2      -5     多云        北风   1-2级   28       优
# 3    2018-01-04       0      -8      阴       东北风   1-2级   28       优
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优
# ..          ...     ...     ...    ...       ...    ...  ...     ...
# 360  2018-12-27      -5     -12   多云~晴       西北风     3级   48       优
# 361  2018-12-28      -3     -11      晴       西北风     3级   40       优
# 362  2018-12-29      -3     -12      晴       西北风     2级   29       优
# 363  2018-12-30      -2     -11   晴~多云       东北风     1级   31       优
# 364  2018-12-31      -2     -10     多云       东北风     1级   56       良
#
#      aqiLevel  wencha tongji
# 0           2       9     常温
# 1           1       7     常温
# 2           1       7     常温
# 3           1       8     常温
# 4           1       9     常温
# ..        ...     ...    ...
# 360         1       7     低温
# 361         1       8     低温
# 362         1       9     低温
# 363         1       9     低温
# 364         2       8     常温
#
# [365 rows x 11 columns]

# %%
df["tongji"].value_counts()
# Out:
# 常温    328
# 高温     29
# 低温      8
# Name: tongji, dtype: int64

# %%
#按条件先选择数据，然后对这部分数据赋值新列
#实例：高低温差大于10度，则认为温差大
df.loc[df['bWendu']-df['yWendu']>=10,'wencha_type']='温差大'
df.loc[df['bWendu']-df['yWendu']<10,'wencha_type']='温差正常'
df
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  \
# 0    2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良
# 1    2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优
# 2    2018-01-03       2      -5     多云        北风   1-2级   28       优
# 3    2018-01-04       0      -8      阴       东北风   1-2级   28       优
# 4    2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优
# ..          ...     ...     ...    ...       ...    ...  ...     ...
# 360  2018-12-27      -5     -12   多云~晴       西北风     3级   48       优
# 361  2018-12-28      -3     -11      晴       西北风     3级   40       优
# 362  2018-12-29      -3     -12      晴       西北风     2级   29       优
# 363  2018-12-30      -2     -11   晴~多云       东北风     1级   31       优
# 364  2018-12-31      -2     -10     多云       东北风     1级   56       良
#
#      aqiLevel  wencha tongji wencha_type
# 0           2       9     常温        温差正常
# 1           1       7     常温        温差正常
# 2           1       7     常温        温差正常
# 3           1       8     常温        温差正常
# 4           1       9     常温        温差正常
# ..        ...     ...    ...         ...
# 360         1       7     低温        温差正常
# 361         1       8     低温        温差正常
# 362         1       9     低温        温差正常
# 363         1       9     低温        温差正常
# 364         2       8     常温        温差正常
#
# [365 rows x 12 columns]

# %%
df['wencha_type'].value_counts()
# Out:
# 温差大     222
# 温差正常    143
# Name: wencha_type, dtype: int64
